# %%
using Pkg

# %%
Pkg.add("PyPlot")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %Fetching: [=====>                                   ]  11.3 %Fetching: [======>                                  ]  13.0 %Fetching: [======>                                  ]  14.7 %Fetching: [=======>                                 ]  16.4 %6 %Fetching: [==============>                          ]  32.9 %Fetching: [================>                        ]  37.9 %Fetching: [=====================>                   ]  51.5 %Fetching: [======================>                  ]  54.4 %Fetching: [=======================>                 ]  57.3 %74.3 %Fetching: [======================================>  ]  92.6 %Fetching: [=======================================> ]  95.3 % Resolving package versions...
#  Installed LibVPX_jll ─────────────────── v1.9.0+1
# ...

# %%
using PyPlot
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1273

# %%
A = [1,2,3,4,5,6,7,8,10]
# Out:
# 8-element Array{Int64,1}:
#  1
#  2
#  3
#  4
#  5
#  6
#  7
#  8

# %%
plot(A, A.^5, "*-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object>
